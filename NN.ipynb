# %% [markdown]
# # NN: backpropagation for b_3

# %% [markdown]
# ## 1/ fitting the network into the data

# %% [markdown]
# fit the curve with the first weight and the first bias then the second to get a line
#
# adjust it to the third and fourth weights

# %% [markdown]
# ## 2/ SSR

# %% [markdown]
# calculate SSR of the curve and sum them up

# %% [markdown]
# ## 3/ chain rule

# %% [markdown]
# SSR derivative with respect to bias_3 calculated using pred

# %% [markdown]
# ## 4/ gradient descent

# %% [markdown]
# sum the SSR derivs
#
# calculate step size by * it with learning rate
#
# b_3 = old b_3 - step size
#
# repeat until step size close to 0

# %% [markdown]
# # backpropagation for w_3 and w_4

# %% [markdown]
# taking two x values for w_3 and w_4 from a normal distribution curve
#
# same steps SSR for w_3 and w_4
#
# calculate w_3 with x * w_1 + b_1 and w_4 with 2s

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pred = ![image.png](attachment:image.png)

# %% [markdown]
# chain rule: SSR deriv with respect to w3

# %% [markdown]
# gradient descent

# %% [markdown]
# # backpropagation with w_1, w_2 and their biases

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# same with b_1

# %% [markdown]
# # ReLU

# %% [markdown]
# plot the activation function ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# where (-) values = 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # RNN (part after gradient boost)

# %% [markdown]
# Used based on recurrent events (e.g stock market)
#
# ![image-2.png](attachment:image-2.png)
# components: today and past days NN, feedback loop, ignore yesterday's output
#
# problem: exploding gradient problem, vanishing gradient problem
