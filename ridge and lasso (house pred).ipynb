# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df = df.drop(['Id', 'Alley', 'FireplaceQu', 'MiscFeature', 'Fence', 'PoolQC'], axis = 1)

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
df['LotFrontage'].unique()
# Out:
# array([ 65.,  80.,  68.,  60.,  84.,  85.,  75.,  nan,  51.,  50.,  70.,
#         91.,  72.,  66., 101.,  57.,  44., 110.,  98.,  47., 108., 112.,
#         74., 115.,  61.,  48.,  33.,  52., 100.,  24.,  89.,  63.,  76.,
#         81.,  95.,  69.,  21.,  32.,  78., 121., 122.,  40., 105.,  73.,
#         77.,  64.,  94.,  34.,  90.,  55.,  88.,  82.,  71., 120., 107.,
#         92., 134.,  62.,  86., 141.,  97.,  54.,  41.,  79., 174.,  99.,
#         67.,  83.,  43., 103.,  93.,  30., 129., 140.,  35.,  37., 118.,
#         87., 116., 150., 111.,  49.,  96.,  59.,  36.,  56., 102.,  58.,
#         38., 109., 130.,  53., 137.,  45., 106., 104.,  42.,  39., 144.,
#        114., 128., 149., 313., 168., 182., 138., 160., 152., 124., 153.,
#         46.])

# %%
df["MasVnrType"].unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn', nan], dtype=object)

# %%
df["MasVnrArea"].unique()
# Out:
# array([1.960e+02, 0.000e+00, 1.620e+02, 3.500e+02, 1.860e+02, 2.400e+02,
#        2.860e+02, 3.060e+02, 2.120e+02, 1.800e+02, 3.800e+02, 2.810e+02,
#        6.400e+02, 2.000e+02, 2.460e+02, 1.320e+02, 6.500e+02, 1.010e+02,
#        4.120e+02, 2.720e+02, 4.560e+02, 1.031e+03, 1.780e+02, 5.730e+02,
#        3.440e+02, 2.870e+02, 1.670e+02, 1.115e+03, 4.000e+01, 1.040e+02,
#        5.760e+02, 4.430e+02, 4.680e+02, 6.600e+01, 2.200e+01, 2.840e+02,
#        7.600e+01, 2.030e+02, 6.800e+01, 1.830e+02, 4.800e+01, 2.800e+01,
#        3.360e+02, 6.000e+02, 7.680e+02, 4.800e+02, 2.200e+02, 1.840e+02,
#        1.129e+03, 1.160e+02, 1.350e+02, 2.660e+02, 8.500e+01, 3.090e+02,
#        1.360e+02, 2.880e+02, 7.000e+01, 3.200e+02, 5.000e+01, 1.200e+02,
#        4.360e+02, 2.520e+02, 8.400e+01, 6.640e+02, 2.260e+02, 3.000e+02,
#        6.530e+02, 1.120e+02, 4.910e+02, 2.680e+02, 7.480e+02, 9.800e+01,
#        2.750e+02, 1.380e+02, 2.050e+02, 2.620e+02, 1.280e+02, 2.600e+02,
# ...

# %%
df["BsmtQual"].unique()
# Out:
# array(['Gd', 'TA', 'Ex', nan, 'Fa'], dtype=object)

# %%
df['BsmtCond'].unique()
# Out:
# array(['TA', 'Gd', nan, 'Fa', 'Po'], dtype=object)

# %%
df['BsmtExposure'].unique()
# Out:
# array(['No', 'Gd', 'Mn', 'Av', nan], dtype=object)

# %%
df['BsmtFinType1'].unique()
# Out:
# array(['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', nan, 'LwQ'], dtype=object)

# %%
df['BsmtFinType2'].unique()
# Out:
# array(['Unf', 'BLQ', nan, 'ALQ', 'Rec', 'LwQ', 'GLQ'], dtype=object)

# %%
df['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
df["GarageType"].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types'],
#       dtype=object)

# %%
df["GarageYrBlt"].unique()
# Out:
# array([2003., 1976., 2001., 1998., 2000., 1993., 2004., 1973., 1931.,
#        1939., 1965., 2005., 1962., 2006., 1960., 1991., 1970., 1967.,
#        1958., 1930., 2002., 1968., 2007., 2008., 1957., 1920., 1966.,
#        1959., 1995., 1954., 1953.,   nan, 1983., 1977., 1997., 1985.,
#        1963., 1981., 1964., 1999., 1935., 1990., 1945., 1987., 1989.,
#        1915., 1956., 1948., 1974., 2009., 1950., 1961., 1921., 1900.,
#        1979., 1951., 1969., 1936., 1975., 1971., 1923., 1984., 1926.,
#        1955., 1986., 1988., 1916., 1932., 1972., 1918., 1980., 1924.,
#        1996., 1940., 1949., 1994., 1910., 1978., 1982., 1992., 1925.,
#        1941., 2010., 1927., 1947., 1937., 1942., 1938., 1952., 1928.,
#        1922., 1934., 1906., 1914., 1946., 1908., 1929., 1933.])

# %%
df["GarageFinish"].unique()
# Out:
# array(['RFn', 'Unf', 'Fin', nan], dtype=object)

# %%
df['GarageQual'].unique()
# Out:
# array(['TA', 'Fa', 'Gd', nan, 'Ex', 'Po'], dtype=object)

# %%
df['GarageCond'].unique()
# Out:
# array(['TA', 'Fa', nan, 'Gd', 'Po', 'Ex'], dtype=object)

# %%
df["LotFrontage"].fillna(df['LotFrontage'].mean(), inplace=True)

# %%
cols = df[['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']]

# %%
from sklearn.preprocessing import LabelEncoder

cols = cols.apply(LabelEncoder().fit_transform)
cols
# Out:
# /home/ines/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#       MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  \
# 0            3       1         3            3          0          4
# 1            3       1         3            3          0          2
# 2            3       1         0            3          0          4
# 3            3       1         0            3          0          0
# 4            3       1         0            3          0          2
# ...        ...     ...       ...          ...        ...        ...
# 1455         3       1         3            3          0          4
# 1456         3       1         3            3          0          4
# 1457         3       1         3            3          0          4
# ...

# %%
df_dr = df.drop(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'], axis = 1)

# %%
df_jn = df_dr.join(cols)

# %%
df_jn
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
df_jn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   LotFrontage    1460 non-null   float64
#  2   LotArea        1460 non-null   int64
#  3   OverallQual    1460 non-null   int64
#  4   OverallCond    1460 non-null   int64
#  5   YearBuilt      1460 non-null   int64
#  6   YearRemodAdd   1460 non-null   int64
#  7   MasVnrArea     1452 non-null   float64
#  8   BsmtFinSF1     1460 non-null   int64
#  9   BsmtFinSF2     1460 non-null   int64
#  10  BsmtUnfSF      1460 non-null   int64
#  11  TotalBsmtSF    1460 non-null   int64
#  12  1stFlrSF       1460 non-null   int64
#  13  2ndFlrSF       1460 non-null   int64
#  14  LowQualFinSF   1460 non-null   int64
#  15  GrLivArea      1460 non-null   int64
#  16  BsmtFullBath   1460 non-null   int64
#  17  BsmtHalfBath   1460 non-null   int64
# ...

# %%
first_column = df_jn.pop('SalePrice')
df_jn.insert(0, 'SalePrice', first_column)

# %%
df_jn
# Out:
#       SalePrice  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        208500          60         65.0     8450            7            5
# 1        181500          20         80.0     9600            6            8
# 2        223500          60         68.0    11250            7            5
# 3        140000          70         60.0     9550            7            5
# 4        250000          60         84.0    14260            8            5
# ...         ...         ...          ...      ...          ...          ...
# 1455     175000          60         62.0     7917            6            5
# 1456     210000          20         85.0    13175            6            6
# 1457     266500          70         66.0     9042            7            9
# 1458     142125          20         68.0     9717            5            6
# 1459     147500          20         75.0     9937            5            6
#
# ...

# %%
pd.set_option('display.max_rows', len(df_jn))
pd.set_option('display.max_columns', len(df_jn))
df_corr = df_jn.corr()
df_corr
# Out:
#                SalePrice  MSSubClass   LotFrontage   LotArea  OverallQual  \
# SalePrice       1.000000   -0.084284  3.349009e-01  0.263843     0.790982
# MSSubClass     -0.084284    1.000000 -3.570559e-01 -0.139781     0.032628
# LotFrontage     0.334901   -0.357056  1.000000e+00  0.306795     0.234196
# LotArea         0.263843   -0.139781  3.067946e-01  1.000000     0.105806
# OverallQual     0.790982    0.032628  2.341962e-01  0.105806     1.000000
# OverallCond    -0.077856   -0.059316 -5.282010e-02 -0.005636    -0.091932
# YearBuilt       0.522897    0.027850  1.175980e-01  0.014228     0.572323
# YearRemodAdd    0.507101    0.040581  8.274589e-02  0.013788     0.550684
# MasVnrArea      0.477493    0.022936  1.796999e-01  0.104160     0.411876
# BsmtFinSF1      0.386420   -0.069836  2.158284e-01  0.214103     0.239666
# BsmtFinSF2     -0.011378   -0.065649  4.333957e-02  0.111170    -0.059119
# BsmtUnfSF       0.214479   -0.140759  1.221556e-01 -0.002618     0.308159
# ...

# %%
# + : overallQual, GrLivArea, GarageArea, GarageCars, 1stFlrSF, TotalBsmtSF
# - : ExterQual, BsmtQual

# %%
X = df_jn[['OverallQual', 'GrLivArea', 'GarageArea', 'GarageCars', '1stFlrSF', 'TotalBsmtSF', 'ExterQual', 'BsmtQual']]
y = df_jn['SalePrice']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df2 = X.join(y)

# %%
df2
# Out:
#       OverallQual  GrLivArea  GarageArea  GarageCars  1stFlrSF  TotalBsmtSF  \
# 0               7       1710         548           2       856          856
# 1               6       1262         460           2      1262         1262
# 2               7       1786         608           2       920          920
# 3               7       1717         642           3       961          756
# 4               8       2198         836           3      1145         1145
# 5               5       1362         480           2       796          796
# 6               8       1694         636           2      1694         1686
# 7               7       2090         484           2      1107         1107
# 8               7       1774         468           2      1022          952
# 9               5       1077         205           1      1077          991
# 10              5       1040         384           1      1040         1040
# ...

# %%
df2.describe()
# Out:
#        OverallQual    GrLivArea   GarageArea   GarageCars     1stFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      6.099315  1515.463699   472.980137     1.767123  1162.626712
# std       1.382997   525.480383   213.804841     0.747315   386.587738
# min       1.000000   334.000000     0.000000     0.000000   334.000000
# 25%       5.000000  1129.500000   334.500000     1.000000   882.000000
# 50%       6.000000  1464.000000   480.000000     2.000000  1087.000000
# 75%       7.000000  1776.750000   576.000000     2.000000  1391.250000
# max      10.000000  5642.000000  1418.000000     4.000000  4692.000000
#
#        TotalBsmtSF    ExterQual     BsmtQual      SalePrice
# count  1460.000000  1460.000000  1460.000000    1460.000000
# mean   1057.429452     2.539726     2.305479  180921.195890
# std     438.705324     0.693995     0.899225   79442.502883
# min       0.000000     0.000000     0.000000   34900.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df2['SalePrice'])
# Out:
# /home/ines/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SalePrice'>

# %%
Q1=df2['SalePrice'].quantile(0.25)
Q2=df2['SalePrice'].quantile(0.75)
IQR = Q2 - Q1
LL=Q1-1.5*IQR
UL=Q2+1.5*IQR
df3 = df2[(df2.SalePrice>LL) & (df2.SalePrice<UL)]
df3.describe()
# Out:
#        OverallQual    GrLivArea   GarageArea   GarageCars     1stFlrSF  \
# count  1399.000000  1399.000000  1399.000000  1399.000000  1399.000000
# mean      5.983560  1474.413867   458.817012     1.717655  1132.247320
# std       1.282272   480.552421   204.278673     0.721365   357.318243
# min       1.000000   334.000000     0.000000     0.000000   334.000000
# 25%       5.000000  1119.000000   312.000000     1.000000   870.500000
# 50%       6.000000  1437.000000   471.000000     2.000000  1069.000000
# 75%       7.000000  1728.000000   573.000000     2.000000  1346.500000
# max      10.000000  5642.000000  1418.000000     4.000000  4692.000000
#
#        TotalBsmtSF    ExterQual     BsmtQual      SalePrice
# count  1399.000000  1399.000000  1399.000000    1399.000000
# mean   1024.273767     2.600429     2.381701  170237.127234
# std     407.031806     0.602593     0.815695   59230.130817
# min       0.000000     0.000000     0.000000   34900.000000
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

plt.figure(figsize = (15,30))
plotnumber = 1

for column in df3:
    if plotnumber <= 30:
        ax = plt.subplot(6, 2, plotnumber)
        sns.distplot(df3[column])
        plt.xlabel(column, fontsize = 15, color = 'w')
        plt.xticks(color = 'w')
        plt.yticks(color = 'w')
    plotnumber += 1

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def draw_axvlines(plt, col):
    mean = df_sum.loc["mean", col]
    q1 = df_sum.loc["25%", col]
    q2 = df_sum.loc["50%", col]
    q3 = df_sum.loc["75%", col]
    plt.axvline(mean, color = 'g')
    plt.axvline(q1, color = "b");               
    plt.axvline(q2, color = "navy");            
    plt.axvline(q3, color = "purple");           
    plt.legend({"Mean": mean, "25%" : q1, "50%" : q2, "75%" : q3});

# %%
'OverallQual', 'GrLivArea', 'GarageArea', 'GarageCars', '1stFlrSF', 
'TotalBsmtSF', 'ExterQual', 'BsmtQual'
# Out:
# ('TotalBsmtSF', 'ExterQual', 'BsmtQual')

# %%
#define outliers
red_circle = dict(markerfacecolor= 'red', marker = 'o', markeredgecolor = 'white')
fig, axs = plt.subplots(1, len(X.columns), figsize=(20,10))
#enumerate: keep track of values
for i, ax in enumerate(axs.flat):
    ax.boxplot(X.iloc[:,i], flierprops = red_circle)
    ax.set_title(X.columns[i], fontsize  = 20, fontweight = 'bold', color = 'w')
    ax.tick_params(axis = 'y', labelsize=14, colors = 'white')
#space out
plt.tight_layout()

# %%
cat_col = ['OverallQual', 'GarageCars', 'ExterQual', 'BsmtQual']
title = ['OverallQual', 'GarageCars', 'ExterQual', 'BsmtQual']

plt.figure(figsize=(7, 14))
for i, variable in enumerate(cat_col):
    plt.subplot(5,2,i+1)
    order = X[variable].value_counts(
        ascending=False).index   
    sns.set_palette('Set2')
    ax=sns.countplot(x=X[variable], data=X)
    sns.despine(top=True,right=True,left=True)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/len(X[variable]))
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        plt.annotate(percentage, (x, y),ha='center')
        plt.xticks(color = 'w')
        plt.yticks(color = 'w')
    plt.tight_layout()
    plt.title(title[i].upper(), color = 'w')

# %%
df_jn["SalePrice"].unique()
# Out:
# array([208500, 181500, 223500, 140000, 250000, 143000, 307000, 200000,
#        129900, 118000, 129500, 345000, 144000, 279500, 157000, 132000,
#        149000,  90000, 159000, 139000, 325300, 139400, 230000, 154000,
#        256300, 134800, 306000, 207500,  68500,  40000, 149350, 179900,
#        165500, 277500, 309000, 145000, 153000, 109000,  82000, 160000,
#        170000, 130250, 141000, 319900, 239686, 249700, 113000, 127000,
#        177000, 114500, 110000, 385000, 130000, 180500, 172500, 196500,
#        438780, 124900, 158000, 101000, 202500, 219500, 317000, 180000,
#        226000,  80000, 225000, 244000, 185000, 144900, 107400,  91000,
#        135750, 136500, 193500, 153500, 245000, 126500, 168500, 260000,
#        174000, 164500,  85000, 123600, 109900,  98600, 163500, 133900,
#        204750, 214000,  94750,  83000, 128950, 205000, 178000, 118964,
#        198900, 169500, 100000, 115000, 190000, 136900, 383970, 217000,
# ...

# %%
sale_counts = pd.DataFrame(df_jn['SalePrice'].value_counts()).reset_index()
sale_counts.columns = ['label', 'Sale_price']
sale_counts["Sale_price"]
# Out:
# 0      20
# 1      17
# 2      14
# 3      14
# 4      13
# 5      13
# 6      12
# 7      12
# 8      11
# 9      11
# 10     10
# 11     10
# 12     10
# 13     10
# 14     10
# 15      9
# 16      9
# 17      9
# 18      9
# 19      8
# 20      8
# 21      8
# 22      8
# 23      8
# 24      8
# 25      8
# 26      8
# 27      8
# 28      7
# 29      7
# 30      7
# 31      7
# 32      7
# 33      7
# 34      7
# 35      7
# 36      7
# 37      7
# 38      6
# 39      6
# 40      6
# 41      6
# 42      6
# 43      6
# 44      6
# 45      6
# 46      6
# 47      6
# 48      6
# 49      6
# 50      6
# 51      6
# 52      6
# 53      6
# 54      6
# 55      6
# 56      6
# 57      5
# 58      5
# 59      5
# 60      5
# 61      5
# 62      5
# 63      5
# 64      5
# 65      5
# 66      5
# 67      5
# 68      5
# 69      5
# 70      5
# 71      5
# 72      5
# 73      4
# 74      4
# 75      4
# 76      4
# 77      4
# 78      4
# 79      4
# 80      4
# 81      4
# 82      4
# ...

# %%
df_4 = df_jn.join(sale_counts)

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(df_4.GrLivArea, df_4.OverallQual, hue = df_4["Sale_price"], palette='deep')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='OverallQual'>

# %% [markdown]
# # Ridge

# %%
from sklearn.linear_model import Ridge
m = 20
X = df_jn[['OverallQual', 'GrLivArea', 'GarageArea', 'GarageCars', '1stFlrSF', 
'TotalBsmtSF', 'ExterQual', 'BsmtQual']]
y = df_jn['SalePrice']

# %%
X.to_numpy
# Out:
# <bound method DataFrame.to_numpy of       OverallQual  GrLivArea  GarageArea  GarageCars  1stFlrSF  TotalBsmtSF  \
# 0               7       1710         548           2       856          856
# 1               6       1262         460           2      1262         1262
# 2               7       1786         608           2       920          920
# 3               7       1717         642           3       961          756
# 4               8       2198         836           3      1145         1145
# 5               5       1362         480           2       796          796
# 6               8       1694         636           2      1694         1686
# 7               7       2090         484           2      1107         1107
# 8               7       1774         468           2      1022          952
# 9               5       1077         205           1      1077          991
# 10              5       1040         384           1      1040         1040
# ...

# %%
X.describe()
# Out:
#        OverallQual    GrLivArea   GarageArea   GarageCars     1stFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      6.099315  1515.463699   472.980137     1.767123  1162.626712
# std       1.382997   525.480383   213.804841     0.747315   386.587738
# min       1.000000   334.000000     0.000000     0.000000   334.000000
# 25%       5.000000  1129.500000   334.500000     1.000000   882.000000
# 50%       6.000000  1464.000000   480.000000     2.000000  1087.000000
# 75%       7.000000  1776.750000   576.000000     2.000000  1391.250000
# max      10.000000  5642.000000  1418.000000     4.000000  4692.000000
#
#        TotalBsmtSF    ExterQual     BsmtQual
# count  1460.000000  1460.000000  1460.000000
# mean   1057.429452     2.539726     2.305479
# std     438.705324     0.693995     0.899225
# min       0.000000     0.000000     0.000000
# 25%     795.750000     2.000000     2.000000
# 50%     991.500000     3.000000     2.000000
# ...

# %%
import numpy as np
X_new = np.linspace(0, 6110, 800).reshape(100,8)

# %% [markdown]
# ## Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(X)
# Out:
# array([[ 0.65147924,  0.37033344,  0.35100032, ..., -0.45930254,
#         -0.77797579, -0.33983046],
#        [-0.07183611, -0.48251191, -0.06073101, ...,  0.46646492,
#          0.66345144, -0.33983046],
#        [ 0.65147924,  0.51501256,  0.63172623, ..., -0.31336875,
#         -0.77797579, -0.33983046],
#        ...,
#        [ 0.65147924,  1.56964722, -1.03391416, ...,  0.21564122,
#         -3.66083024,  0.77261903],
#        [-0.79515147, -0.83278768, -1.09005935, ...,  0.04690528,
#          0.66345144,  0.77261903],
#        [-0.79515147, -0.49393395, -0.9216238 , ...,  0.45278362,
#         -0.77797579,  0.77261903]])

# %% [markdown]
# ## Poly

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2, include_bias = False)
X_poly = poly.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25 , random_state=1)

# %%
l_reg = LinearRegression()
model = l_reg.fit(X_train, y_train)
y_pred =model.predict(X_test)

# %% [markdown]
# https://www.mygreatlearning.com/blog/what-is-ridge-regression/

# %%
from pandas import Series, DataFrame
predictors = X_train.columns
coef = Series(l_reg.coef_.flatten(), predictors).sort_values()
plt.figure(figsize=(10,8))
coef.plot(kind='bar', title='Model Coefficients')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
ridge = Ridge()
parm = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
ridge_reg = GridSearchCV(ridge,parm,scoring='neg_mean_squared_error',cv=5)
ridge_reg.fit(X, y)
print(ridge_reg.best_params_)
print(ridge_reg.best_score_)
# Out:
# {'alpha': 50}
# -1432222883.0193038

# %%
predictors = X_train.columns
 
coef = Series(ridge.coef_.flatten(),predictors).sort_values()
plt.figure(figsize=(10,8))
coef.plot(kind='bar', title='Model Coefficients')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [123], in <cell line: 3>()
#       1 predictors = X_train.columns
# ----> 3 coef = Series(ridge.coef_.flatten(),predictors).sort_values()
#       4 plt.figure(figsize=(10,8))
#       5 coef.plot(kind='bar', title='Model Coefficients')
#
# AttributeError: 'Ridge' object has no attribute 'coef_'

# %%
def plot_model(model_class, polynomial, alphas, **model_kargs):
    for alpha, style in zip(alphas, ("b-", "g--", 'r:')):
        #instantiate reg
        model = model_class(alpha, **model_kargs) if alpha > 0 else LinearRegression()
        if polynomial:
            model = Pipeline([
                ('poly', PolynomialFeatures(degree = 10, include_bias = False)),
                ('scaler', StandardScaler()),
                ("regul_reg", model),
            ])
        model.fit(X, y)
        y_new_regul = model.predict(X_new)
        lw = 2 if alpha > 0 else 1
        plt.plot(X_new, y_new_regul, style, linewidth=lw, label = r'$\alpha= {}$'.format(alpha))
    plt.plot(X, y, 'b.', linewidth = 3)
    plt.legend(fontsize=15)
    plt.xlabel("$x_1$")
    plt.axis([0,3, 0,4])
    
plt.figure(figsize=(8,4))
plt.subplot(121);
plot_model(Ridge, polynomial = False, alphas = (0, 10, 100), random_state = 42)
plt.subplot(122);
plot_model(Ridge, polynomial = True,alphas = (0,10**-5,100), random_state=42)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), None)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [113], in <cell line: 22>()
#      20 plt.figure(figsize=(8,4))
#      21 plt.subplot(121);
# ...
